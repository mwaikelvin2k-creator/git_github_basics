# %% [markdown]
# ## Pseudocode
# Function pizza cost(pizza size,number of toppings,delivery distance)
# >Collect information on the various pizza costs against pizza size and store it in the data base
# >retrieve user preference on number of toppings and delivery distance and store it in the database.
#
# Function additionalpizza cost(number of toppings)
# >retrieve data on the costing of pizza  against number of toppings.
# >calculate by multiplying the number of toppings against $1
# >therefore total topping cost==toppings*$1
#
# Function pizza size(small,large)
# >Prompt user to select between the sizes of the pizza
# >If small then cost==$8
# else cost==$12
#
# Function additional pizza cost(Delivery fee)
# >calculate delivery fee per mile.
# >where the first five miles==$2 and >>additional miles is $1 per mile.
#
# Terminate all
